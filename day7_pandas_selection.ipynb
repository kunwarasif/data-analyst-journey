# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
print(df)
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar

# %%
print(df.columns)
print(list(df.columns))
# Out:
# Index(['salesperson', 'amount', 'month'], dtype='object')
# ['salesperson', 'amount', 'month']

# %%
print("amount" in df.columns)
print("revenue" in df.columns)
# Out:
# True
# False

# %%
print(df.amount)
print(df["amount"])
# Out:
# 0    50000
# 1    75000
# 2    60000
# 3    80000
# 4    45000
# 5    90000
# 6    55000
# Name: amount, dtype: int64
# 0    50000
# 1    75000
# 2    60000
# 3    80000
# 4    45000
# 5    90000
# 6    55000
# Name: amount, dtype: int64

# %%
columns_i_need = ["salesperson", "amount"]
result = df[columns_i_need]
print(result)
print(type(result))
# Out:
#   salesperson  amount
# 0       Rohit   50000
# 1        Amit   75000
# 2       Rohit   60000
# 3        Neha   80000
# 4        Amit   45000
# 5        Neha   90000
# 6       Rohit   55000
# <class 'pandas.core.frame.DataFrame'>

# %%
print("=== Original DataFrame ===")
print(df)

print("\n=== same data, but with custom index ===")
df_custom = df.copy()
df_custom.index = ["a", "b", "c", "d", "e", "f", "g"]
print(df_custom)
# Out:
# === Original DataFrame ===
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar
#
# === same data, but with custom index ===
#   salesperson  amount month
# a       Rohit   50000   Jan
# b        Amit   75000   Jan
# c       Rohit   60000   Feb
# d        Neha   80000   Feb
# e        Amit   45000   Feb
# f        Neha   90000   Mar
# g       Rohit   55000   Mar

# %%
print("--- original df.iloc[3] ---")
print(df.iloc[3])

print("\n--- original df.loc[3] ---")
print(df.loc[3])
# Out:
# --- original df.iloc[3] ---
# salesperson     Neha
# amount         80000
# month            Feb
# Name: 3, dtype: object
#
# --- original df.loc[3] ---
# salesperson     Neha
# amount         80000
# month            Feb
# Name: 3, dtype: object

# %%
print("--- custom df_custom.iloc[3] ---")
print(df_custom.iloc[3])

print("\n--- custom df_custom.loc[3] ---")
print(df_custom.loc["d"])
# Out:
# --- custom df_custom.iloc[3] ---
# salesperson     Neha
# amount         80000
# month            Feb
# Name: d, dtype: object
#
# --- custom df_custom.loc[3] ---
# salesperson     Neha
# amount         80000
# month            Feb
# Name: d, dtype: object

# %%
print(df.iloc[[0, 2, 4]])     
print(df.loc[[0, 2, 4]])
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 2       Rohit   60000   Feb
# 4        Amit   45000   Feb
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 2       Rohit   60000   Feb
# 4        Amit   45000   Feb

# %%
print(df.iloc[2, 1])
print(df.loc[2, "amount"])
# Out:
# 60000
# 60000

# %%
print(df.loc[[0, 2, 4], ["salesperson", "amount"]])
# Out:
#   salesperson  amount
# 0       Rohit   50000
# 2       Rohit   60000
# 4        Amit   45000

# %%
print(df.iloc[1:4])
print(df.loc[1:4])
# Out:
#   salesperson  amount month
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
#   salesperson  amount month
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
print(df.iloc[0])
# Out:
# salesperson    Rohit
# amount         50000
# month            Jan
# Name: 0, dtype: object

# %%
print(df.iloc[0:3])
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb

# %%
print(df.loc[0:3])
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb

# %%
print(df.loc[2, "salesperson"])
# Out:
# Rohit

# %%
print(df.iloc[[1, 3], [0, 2]])
# Out:
#   salesperson month
# 1        Amit   Jan
# 3        Neha   Feb

# %%
mask = df["amount"] > 60000
print(mask)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: amount, dtype: bool

# %%
big_sales = df[mask]
print(big_sales)
# Out:
#   salesperson  amount month
# 1        Amit   75000   Jan
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar

# %%
big_sales = df[df["amount"] > 60000]
print(big_sales)
# Out:
#   salesperson  amount month
# 1        Amit   75000   Jan
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar

# %%
df[df["salesperson"] == "Neha"]
# Out:
#   salesperson  amount month
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar

# %%
df[df["month"].isin(["Jan", "Feb"])]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
df[df["salesperson"].str.startswith("R")]   
df[df["salesperson"].str.contains("e")]
# Out:
#   salesperson  amount month
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar

# %%
df[df["amount"] > 50000]
# Out:
#   salesperson  amount month
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar

# %%
df[df["salesperson"] == "Rohit"]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 2       Rohit   60000   Feb
# 6       Rohit   55000   Mar

# %%
df[df["month"] == "Mar"]
# Out:
#   salesperson  amount month
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar

# %%
df[df["salesperson"].str.contains("a")]
# Out:
#   salesperson  amount month
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar

# %%
df[df["month"].isin(["Jan", "Mar"])]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar

# %%
# Rohit's big sales (Rohit AND amount > 50000)
df[(df["salesperson"] == "Rohit") & (df["amount"] > 50000)]
# Out:
#   salesperson  amount month
# 2       Rohit   60000   Feb
# 6       Rohit   55000   Mar

# %%
# January or February sales
df[(df["month"] == "Jan") | (df["month"] == "Feb")]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
# Same thing, cleaner with .isin()
df[df["month"].isin(["Jan", "Feb"])]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
# Sales NOT in March
df[~(df["month"] == "Mar")]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
# Equivalent to above, slightly cleaner
df[df["month"] != "Mar"]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
df["amount"] > 50000 & df["salesperson"] == "Rohit"
# Python tries to do: 50000 & df["salesperson"]  ← nonsense
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)    360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df[
    (df["salesperson"] == "Rohit") & 
    (df["month"] == "Jan") & 
    (df["amount"] > 40000)
]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan

# %%
# Q1: Rohit's sales above 50000
df[(df["salesperson"] == "Rohit") & (df["amount"] > 50000)]
# Out:
#   salesperson  amount month
# 2       Rohit   60000   Feb
# 6       Rohit   55000   Mar

# %%
# Q2: Sales NOT by Neha
df[df["salesperson"] != "Neha"]
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 4        Amit   45000   Feb
# 6       Rohit   55000   Mar

# %%
# Q3: Big sales (>60000) in Feb or Mar
df[(df["amount"] > 60000) & (df["month"].isin(["Feb", "Mar"]))]
# Out:
#   salesperson  amount month
# 3        Neha   80000   Feb
# 5        Neha   90000   Mar

# %%
# Q4: All sales by Amit OR Neha
df[df["salesperson"].isin(["Amit", "Neha"])]
# Out:
#   salesperson  amount month
# 1        Amit   75000   Jan
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb
# 5        Neha   90000   Mar

# %%
# Q5: Small sales (<50000) NOT in January
df[(df["amount"] < 50000) & (df["month"] != "Jan")]
# Out:
#   salesperson  amount month
# 4        Amit   45000   Feb
