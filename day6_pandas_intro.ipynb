# %% [markdown]
# Pandas is intresting can replace 60-70 lines of code into one line.
# Nothing hard till now,
# One thing I'm curious about for tomorrow
# operations on dataset.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
pd.Series(["Rohit", "Amit", "Neha"])
# Out:
# 0    Rohit
# 1     Amit
# 2     Neha
# dtype: object

# %%
pd.Series([25, 30, 28, 35])
# Out:
# 0    25
# 1    30
# 2    28
# 3    35
# dtype: int64

# %%
data = {
    "name": ["Rohit", "Amit", "Neha"],
    "age": [25, 30, 28],
    "city": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age    city
# 0  Rohit   25   Delhi
# 1   Amit   30  Mumbai
# 2   Neha   28    Pune

# %%
data = {
    "name": ["Rohit", "Amit", "Neha"],
    "age": [25, 30, 28],
    "city": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age    city
# 0  Rohit   25   Delhi
# 1   Amit   30  Mumbai
# 2   Neha   28    Pune

# %%
print(df["name"])
print(type(df["name"]))
# Out:
# 0    Rohit
# 1     Amit
# 2     Neha
# Name: name, dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(df[["name", "age"]])
print(type(df[["name", "age"]]))
# Out:
#     name  age
# 0  Rohit   25
# 1   Amit   30
# 2   Neha   28
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df[["name"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv("sales_data.csv")
print(df)
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar

# %%
df.head()
# Out:
#   salesperson  amount month
# 0       Rohit   50000   Jan
# 1        Amit   75000   Jan
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb

# %%
df.tail()
# Out:
#   salesperson  amount month
# 2       Rohit   60000   Feb
# 3        Neha   80000   Feb
# 4        Amit   45000   Feb
# 5        Neha   90000   Mar
# 6       Rohit   55000   Mar

# %%
df.shape
# Out:
# (7, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   salesperson  7 non-null      object
#  1   amount       7 non-null      int64
#  2   month        7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %% [raw]
# df.describe()

# %%
df.columns
# Out:
# Index(['salesperson', 'amount', 'month'], dtype='object')

# %%
df.dtypes
# Out:
# salesperson    object
# amount          int64
# month          object
# dtype: object

# %%
print(df.describe())
# Out:
#              amount
# count      7.000000
# mean   65000.000000
# std    16832.508231
# min    45000.000000
# 25%    52500.000000
# 50%    60000.000000
# 75%    77500.000000
# max    90000.000000

# %%
from IPython.display import display
display(df.describe())
# Out:
#              amount
# count      7.000000
# mean   65000.000000
# std    16832.508231
# min    45000.000000
# 25%    52500.000000
# 50%    60000.000000
# 75%    77500.000000
# max    90000.000000
